# %% [markdown]
# <a href="https://colab.research.google.com/github/sourabh-bhide/plant-seg/blob/master/PlantSeg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Initialise server
# You will try to setup a server in this cell. Before you start go to Runtime/Change runtime type and select "GPU" as the hardware accelerator.
# If done correctly you will see the details of the GPU

# %%
import tensorflow as tf
if tf.test.gpu_device_name()=='':
  print('NO GPU access. Check runtime settings') 
else:
  # !nvidia-smi
# Out:
# Tue Dec 15 15:46:32 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.45.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    32W / 250W |    359MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # Mount your Google Drive
# This cell will initialise a connection to your Google drive. Make sure to save the data that you want to process on your Google drive preferably in a seperate folder.

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Install miniconda3
# You can download and install miniconda. This is the basic form of conda. Sufficient to download conda libraries like PlantSeg

# %%
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# --2020-12-15 15:16:46--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M   111MB/s    in 0.7s
#
# 2020-12-15 15:16:47 (111 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
# ...

# %% [markdown]
# IMPORTANT to append the correct path to python that will be used

# %%
import sys
sys.path.append("/usr/local/lib/python3.7/site-packages/")

# %% [markdown]
# # Download PlanSeg
# You will now download all the files required to run PlantSeg on this server.

# %%
# !conda create -n plantseg -c lcerrone -c abailoni -c cpape -c awolny -c conda-forge nifty=vplantseg1.0.8 pytorch-3dunet=1.2.5 plantseg
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/plantseg
#
#   added / updated specs:
#     - nifty=vplantseg1.0.8
#     - plantseg
#     - pytorch-3dunet=1.2.5
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |           1_llvm           5 KB  conda-forge
#     _pytorch_select-0.2        |            gpu_0           2 KB
#     asciitree-0.3.3            |             py_2           6 KB  conda-forge
#     blas-1.0                   |              mkl           6 KB
#     blosc-1.20.1               |       h9c3ff4c_0         822 KB  conda-forge
# ...

# %% [markdown]
# Check if plantseg is a conda environment

# %%
# %%bash
# conda env list
# Out:
# # conda environments:
# #
# base                  *  /usr/local
# plantseg                 /usr/local/envs/plantseg

# %% [markdown]
# #RUN PlantSeg
# Before you execute this cell, make sure to open and edit your 'config.yaml' and provide the correct path to the config file.

# %%
# activate your conda environment
# %%bash
source activate plantseg
source update -c lcerrone plantseg
#pip install ipykernel
plantseg --config /content/gdrive/MyDrive/config_files/config.yaml
# Out:
# 2020-12-15 17:01:13,298 [MainThread] INFO PlantSeg - Running the pipeline on: ['/content/gdrive/MyDrive/Ivan_data/NmTBR_C0_T3.tif']
# 2020-12-15 17:01:13,298 [MainThread] INFO PlantSeg - Executing pipeline, see terminal for verbose logs.
# 2020-12-15 17:01:13,298 [MainThread] INFO PlantSeg - Executing pipeline step: 'preprocessing'. Parameters: '{'state': True, 'save_directory': 'PreProcessing', 'factor': [1.0, 1.0, 1.0], 'order': 2, 'filter': {'state': True, 'type': 'gaussian', 'param': 1.0}}'. Files ['/content/gdrive/MyDrive/Ivan_data/NmTBR_C0_T3.tif'].
# 2020-12-15 17:01:13,299 [MainThread] INFO PlantSeg - Loading stack from /content/gdrive/MyDrive/Ivan_data/NmTBR_C0_T3.tif
# 2020-12-15 17:01:14,008 [MainThread] INFO PlantSeg - Preprocessing files...
# 2020-12-15 17:01:17,239 [MainThread] INFO PlantSeg - Saving results in /content/gdrive/MyDrive/Ivan_data/PreProcessing/NmTBR_C0_T3.h5
# ...

# %%
conda create -y -n napari-env python=3.7
conda activate napari-env
pip install napari[all]

# %%
# %%bash
# source activate napari-env
